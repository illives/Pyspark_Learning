# %%
import pyspark.sql.functions as F
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('filter_data')\
.config('spark.sql.repl.eagerEval.enabled', True).getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://CLR0ZN001029994.corp.clarobr:4043">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>filter_data</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.parquet('.//data/DATASETS/DATASETS/LOGINS.parquet')
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
import pandas as pd

pandas_df = df.toPandas()
type(pandas_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# NO pandas ele um dataframe do pyspark e transforma em Pandas

# %%
pd.DataFrame(df.collect(), columns=df.columns)
# Out:
#                 cpf                     email       senha data_de_nascimento  \
# 0    981.507.362-12   pedro-lucas53@gmail.com  +7^7E%xFBc         2006-12-18
# 1    493.705.168-75  rezendeisaac@hotmail.com  _O_2GRnGOe         1992-06-17
# 2    398.471.625-73    felipepires@uol.com.br  *Aw5EOAvy9         1921-11-11
# 3    092.618.354-06   stellamoraes@bol.com.br  mw0AWYAs#s         2021-06-01
# 4    509.427.136-99       wcarvalho@ig.com.br  pGD%!2Pq5X         1969-10-28
# ..              ...                       ...         ...                ...
# 995  073.128.546-80     nicolas11@hotmail.com  hp%24OQsr(         1913-04-05
# 996  841.950.263-42    francisco14@bol.com.br  6^02PPwbKM         1928-07-01
# 997  175.682.043-08     barbara51@hotmail.com  E5B6wYv8!i         1945-08-21
# 998  570.263.819-03      imendes@yahoo.com.br  ^17tb#Fym_         1929-05-18
# 999  651.278.304-26        erick64@uol.com.br  VM9B65Ebc+         1973-01-17
#
# ...

# %% [markdown]
# TRANSFORME PANDAS EM PYSPARK

# %%
import pyspark.pandas as ps
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import pyspark.pandas as ps
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pyspark\pandas\__init__.py:59
#      56     os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"
#      58 from pyspark.pandas.frame import DataFrame
# ---> 59 from pyspark.pandas.indexes.base import Index
#      60 from pyspark.pandas.indexes.category import CategoricalIndex
#      61 from pyspark.pandas.indexes.datetimes import DatetimeIndex
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pyspark\pandas\indexes\__init__.py:17
#       1 #
#       2 # Licensed to the Apache Software Foundation (ASF) under one or more
#       3 # contributor license agreements.  See the NOTICE file distributed with
#    (...)
#      15 # limitations under the License.
#      16 #
# ...
